# %% [markdown]
# # Musubi-Tuner Z-Image Runpod Starter\n\nThis notebook assumes models are under `/workspace/models`, dataset images/captions are in `/workspace/dataset/images`, and scripts are in `/workspace/scripts`.

# %%
# !ls -lah /workspace\n!ls -lah /workspace/scripts\n!ls -lah /workspace/models || true

# %% [markdown]
# ## 1) Upload dataset\nUpload images and matching `.txt` captions into `/workspace/dataset/images` using Jupyter file browser.

# %%
# !ls -lah /workspace/dataset/images | head -n 50

# %% [markdown]
# ## 2) Prepare dataset cache

# %%
# !/workspace/scripts/prepare_dataset.sh

# %% [markdown]
# ## 3) Train with Prodigy (recommended)

# %%
# !/workspace/scripts/train_lora_prodigy.sh

# %% [markdown]
# ## 4) Convert trained LoRA for ComfyUI\nReplace `epoch-XXXX` with your selected checkpoint.

# %%
# !/workspace/scripts/convert_lora.sh /workspace/output/character_lora_v1-epoch-XXXX.safetensors
